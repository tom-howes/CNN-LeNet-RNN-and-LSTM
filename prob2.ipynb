# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-04bbff22-4ca4-4bac-b307-fe46007f9748" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04bbff22-4ca4-4bac-b307-fe46007f9748">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python train.py rnn
# Out:
# Using device: cuda
# Loading data...
# Building vocabularies...
# Source vocab size: 51016
# Target vocab size: 28626
# Loaded 53387 sentence pairs
#
# Training rnn model...
# Model parameters: 36,912,594
#
# Epoch 1/5
# rnn
# Training: 100% 1335/1335 [02:33<00:00,  8.67it/s, loss=5.93]
# Evaluating: 100% 167/167 [00:09<00:00, 16.70it/s]
# Train Loss: 6.2171, Val Loss: 6.2047
# Saved best model with val loss: 6.2047
# === DEBUGGING MODEL OUTPUT ===
#
# --- Example 1 ---
# [288, 548, 550, 23, 24, 149, 592, 12]
# Source: uno habla inglés y el otro japonés.
# [268, 1835, 489, 33, 28, 35, 181, 1835, 528, 8]
# Target: one speaks english, and the other speaks japanese.
# tensor([[288, 548, 550,  23,  24, 149, 592,  12,   0,   0,   0,   0,   0,   0]],
#        device='cuda:0')
# Prediction: don't to. to.
# Raw decoded: [57, 58, 11, 8, 11, 8, 2]
#
# --- Example 2 ---
# [476, 8, 8607, 204, 10, 61, 12]
# Source: parece que llegaremos allí a tiempo.
# ...

# %%
# !python train.py lstm
# Out:
# Using device: cuda
# Loading data...
# Building vocabularies...
# Source vocab size: 51016
# Target vocab size: 28626
# Loaded 53387 sentence pairs
#
# Training lstm model...
# Model parameters: 42,429,906
#
# Epoch 1/5
# lstm
# Training: 100% 1335/1335 [02:45<00:00,  8.06it/s, loss=5.14]
# Evaluating: 100% 167/167 [00:09<00:00, 16.90it/s]
# Train Loss: 5.7382, Val Loss: 5.4635
# Saved best model with val loss: 5.4635
# === DEBUGGING MODEL OUTPUT ===
#
# --- Example 1 ---
# [24, 2801, 17, 142, 3575, 8, 33, 3326, 12]
# Source: el sol es más grande que la luna.
# [35, 2144, 21, 2487, 414, 35, 527, 8]
# Target: the sun is larger than the moon.
# tensor([[  24, 2801,   17,  142, 3575,    8,   33, 3326,   12,    0,    0,    0]],
#        device='cuda:0')
# Prediction: is are is the. the.
# Raw decoded: [21, 15, 21, 35, 8, 35, 8, 2]
#
# --- Example 2 ---
# [1626, 17, 1621, 12]
# Source: traducir es divertido.
# [3582, 21, 1271, 8]
# Target: translating is fun.
# ...
