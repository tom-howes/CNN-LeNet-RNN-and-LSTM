# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ddc59b10-6680-4bb6-a4b2-3e810004a48a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ddc59b10-6680-4bb6-a4b2-3e810004a48a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install torch numpy matplotlib tqdm sacrebleu nltk bert_score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !python train2.py rnn
# Out:
# Using device: cuda
# Loading data...
# Building vocabularies...
# Source vocab size: 51016
# Target vocab size: 28626
# Loaded 53387 sentence pairs
#
# Training rnn model...
# Model parameters: 37,957,074
#
# Epoch 1/5
# rnn
# Training: 100% 1335/1335 [01:20<00:00, 16.57it/s, loss=6.06]
# Evaluating: 100% 167/167 [00:05<00:00, 29.46it/s]
# Train Loss: 6.1992, Val Loss: 6.2437
# Saved best model with val loss: 6.2437
# === DEBUGGING MODEL OUTPUT ===
#
# --- Example 1 ---
# [952, 763, 308, 28, 205, 4156, 12]
# Source: mientras haya vida, hay esperanza.
# [546, 136, 546, 193, 5, 158, 33, 193, 5, 1585, 8]
# Target: as long as there's life, there's hope.
# tensor([[ 952,  763,  308,   28,  205, 4156,   12,    0,    0,    0,    0,    0,
#             0]], device='cuda:0')
# Prediction: is't. to.
# Raw decoded: [21, 58, 8, 11, 8, 2]
#
# --- Example 2 ---
# [17, 57, 833, 21, 1184, 7262, 12]
# Source: es una obra de arte maravillosa.
# [22, 5, 48, 1672, 544, 157, 956, 8]
# ...
